# %%
import Graph_generator as gg
import Plotting as pp
import numpy as np
import Utils
location = '/Users/ryznerf/Documents/0_MIT/Spring_2022/0_Projects/3_Networks_project/community-detetction-deep-learning/Data/'
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
p = 0.5    #probability of edges within a cluster
q = 0.01 #probability of edges across clusters
cluster_size = [10, 10, 25]
g = gg.SBM_generator(cluster_sizes= cluster_size, p = p, q= q, seed= 0)
pp.graph_cluster_plot(g)

# %%
cluster_size = [100,100,100]
p = 0.1
q = 0.02

g = gg.SBM_generator(cluster_sizes= cluster_size, p = p, q= q, seed= np.random.randint(10000))
pp.graph_cluster_plot(g)

# %%
name = 'complex_1.pkl'
Utils.pickle_object(g, location + name)

# %%
cluster_size = [100,250,100]
p = 0.05
q = 0.01

g = gg.SBM_generator(cluster_sizes= cluster_size, p = p, q= q, seed= np.random.randint(10000))
pp.graph_cluster_plot(g)

# %%
name = 'complex_2.pkl'
Utils.pickle_object(g, location + name)
